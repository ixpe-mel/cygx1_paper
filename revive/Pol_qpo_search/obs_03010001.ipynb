# %%
import numpy as np


Pmin=51
Pmax=200

file1 = '/home/c2032014/cygx1_paper/cyg_data_all/03010001/event_1pt5/ixpe01002901_det12_event_1pt5_src.fits'
file2 = '/home/c2032014/cygx1_paper/cyg_data_all/03010001/event_1pt5/ixpe01002901_det3_evt_1pt5_v01_src.fits'



gti='/home/c2032014/cygx1_paper/cyg_data_all/03010001/GTI_ixpe03010001_evt2_v01.txt'
mod_min=np.radians(-90)
mod_max=np.radians(90)
mod_bin_number=20

output_file_L1='/home/c2032014/cygx1_paper/revive/Pol_qpo_search/03010001_L1_51to200P_20bins_90mod_qpo_search.txt'
output_file_L2='/home/c2032014/cygx1_paper/revive/Pol_qpo_search/03010001_L2_51to200P_20bins_90mod_qpo_search.txt'
output_file_L3='/home/c2032014/cygx1_paper/revive/Pol_qpo_search/03010001_L3_51to200P_20bins_90mod_qpo_search.txt'
output_file_L4='/home/c2032014/cygx1_paper/revive/Pol_qpo_search/03010001_L4_51to200P_20bins_90mod_qpo_search.txt'

fmin_L2=0.54711-0.191019
fmax_L2=1.54711+0.191019

fmin_L3=1.09422-0.382028
fmax_L3=1.09422+0.382028







bin_length=1/64
seg_length=16

obs_dir='/home/c2032014/cygx1_paper/cyg_data_all'
obs_name=['03010001']

import sys
sys.path.append('/home/c2032014/cygx1_paper/')
import QPO_finder_abs_NOSTACK as qfans

# %%
import importlib
importlib.reload(qfans)
result_L3= qfans.qfans(obs_dir,obs_name,Pmin,Pmax,bin_length,seg_length,fmin_L3,fmax_L3,True,'abs',mod_bin_number,coherence_corrector=False)
# Out:
# (0.184453154765443, 0.16761355492693603, 0.1964113625986822, 0.13449812358299862, 0.17621454945833032, 0.1628669601463522, 0.1781045649119352, 0.17221300650456536, 0.18083458428014584, 0.18439698391552978, 0.17057444469283653, 0.1349242867728382, 0.1832178138833498, 0.1850056937635299, 0.21608448736793243, 0.20946281984044082, 0.1786918387019455, 0.19351987314528507, 0.18677788975084889, 0.17704291998576643)
# (-0.00198403753685357, -0.021125189978941767, 0.04784845405517237, -0.017908814275417587, 0.02288627337130414, 0.015335608118758264, 0.021295213944117253, 0.003470960088414051, -0.018264890888470685, -0.00437652830847845, -0.021018790792902198, -0.03155618284577807, 0.010933429345034327, -0.000355007312803428, 0.015510960803412997, -0.06662776656789585, 0.012798088281135628, -0.04412355809181971, -0.0031789186453381932, 0.03579673802040625)
# G_real_span [0.84281189 0.76586761 0.89745189 0.61455505 0.80516767 0.74417925
#  0.81380362 0.78688364 0.82627775 0.84255523 0.77939665 0.61650229
#  0.83716731 0.84533658 0.98734324 0.95708721 0.81648702 0.88423996
#  0.85343418 0.8089527 ]
# G_im_span [-0.00906556 -0.0965262   0.21863137 -0.08182978  0.10457302  0.07007217
#   0.09730308  0.01585967 -0.08345678 -0.01999744 -0.09604003 -0.14418797
#   0.04995753 -0.00162212  0.0708734  -0.30443867  0.05847762 -0.2016114
#  -0.01452526  0.16356411]
# No coherence correction applied
# model_chi_real 13.446824551584273
# dof_model_real 18
# model_chi_imag 28.77604004417679
# dof_model_imag 18
# reduced_chi_model 1.1728573498822517
# chi_real_null_cpf 17.381467527067155
# chi_imag_null_cpf 33.641800100285636
# dof_null_real_cpf 20
# dof_null_imag_cpf 20
# reduced_chi_null_cpf 1.2755816906838198
# chi_real_null 18.88470821358185
# chi_imag_null 33.641800100285636
# dof_null_real 20
# dof_null_imag 20
# reduced_chi_null 1.313162707846687
# Null (2.1962695887826533, 0.08896699528178231, 0.9110330047182177, 1.7008721606749349)
# Null CPF (1.8758468437093492, 0.1359256383152747, 0.8640743616847253, 1.4911365869123334)

# %%
13.446824551584273+ 28.77604004417679
# Out:
# 42.22286459576106

# %%
18.88470821358185+ 33.641800100285636
# Out:
# 52.52650831386748

# %%
17.381467527067155+33.641800100285636
# Out:
# 51.023267627352794

# %%
#unpacking results

aspace = np.linspace(np.radians(-90), np.radians(90), mod_bin_number + 1)
mod_min_array = aspace[:-1]
mod_max_array = aspace[1:]
av_mod = (mod_min_array + mod_max_array) / 2
I_obs_L3=result_L3['I_obs']
Q_obs_L3=result_L3['Q_obs']
U_obs_L3=result_L3['U_obs']
cs_ref_L3=result_L3['cs_ref']
weights_ref_L3=result_L3['weights_ref']
cs_ref_mean_real_L3=result_L3['cs_ref_mean_real']
cs_ref_mean_imag_L3=result_L3['cs_ref_mean_imag']
cs_ref_mean_L3=result_L3['cs_ref_abs_mean_stack']
cs_list_L3=result_L3['cs_list']
weights_G_L3=result_L3['weights_G']
weights_ref_L3=result_L3['weights_ref']
G_real_span_L3=result_L3['G_real_span']
G_im_span_L3=result_L3['G_im_span']
G_null_real_L3=result_L3['G_null_real']
G_null_imag_L3=result_L3['G_null_imag']
G_null_real_cpf_L3=result_L3['G_null_real_cpf']
G_null_imag_cpf_L3=result_L3['G_null_imag_cpf']
dG_span_L3=result_L3['dG_span']
scale_factor_L3=result_L3['scale_factor']
Q_L3=result_L3['Q']
U_L3=result_L3['U']
F_null_L3=result_L3['F_null']
F_null_cpf_L3=result_L3['F_null_cpf']
frac_rms_L3=result_L3['frac_rms']
d_frac_rms_L3=result_L3['d_frac_rms']
phase_lag_L3=result_L3['phase_lag']
d_phase_lag_L3=result_L3['d_phase_lag']
fit_full_real_L3=result_L3['Fit_full_real']
fit_full_imag_L3=result_L3['Fit_full_imag']
frac_rms_model_L3=result_L3['frac_rms_model']
phase_lag_model_L3=result_L3['phase_lag_model']
frac_rms_null_L3=result_L3['frac_rms_null']
phase_lag_null_L3=result_L3['phase_lag_null']
frac_rms_null_cpf_L3=result_L3['frac_rms_null_cpf']
phase_lag_null_cpf_L3=result_L3['phase_lag_null_cpf']

# %%
xerr=(av_mod[1]-av_mod[0])/2

# %%
import importlib
importlib.reload(qfans)
result_L2= qfans.qfans(obs_dir,obs_name,Pmin,Pmax,bin_length,seg_length,fmin_L2,fmax_L2,True,'abs',mod_bin_number,coherence_corrector=False)
# Out:
# (0.2400278006978352, 0.2257414430190093, 0.23691381807122985, 0.21373894578437808, 0.22193394663974034, 0.20781808658410542, 0.2244858219428948, 0.21533468899957847, 0.2240903485811907, 0.2325941932660394, 0.2024604780602927, 0.21207001116697438, 0.20663341656238823, 0.22855389962570097, 0.2268927670864599, 0.22799869146018567, 0.21586262832821734, 0.20595096221767553, 0.21936200073139525, 0.21894470389218565)
# (0.016247688132266014, -0.010841399585512298, 0.011738834513177388, -0.015142612686882478, 0.02423633101749212, 0.008584598836763815, -0.0049547360663458224, -0.00018889684792995263, -0.018227484550344376, -0.008453999027362723, -0.013783015199073538, -0.001618199908609526, -0.0038150770105039246, -0.008014838894811764, 0.0077214297277121745, -0.027900550363871547, -0.014585984470802095, -0.03290542551243732, -0.004244455756102073, 0.0193642844330207)
# G_real_span [1.09674613 1.03146825 1.08251758 0.97662588 1.01407086 0.94957202
#  1.02573101 0.98391723 1.02392399 1.06278015 0.92509179 0.96900011
#  0.94415897 1.04431905 1.03672893 1.04178217 0.98632951 0.94104067
#  1.002319   1.00041227]
# G_im_span [ 0.07423969 -0.04953702  0.05363763 -0.06919033  0.11074177  0.03922515
#  -0.02263941 -0.00086312 -0.08328587 -0.0386284  -0.06297799 -0.00739395
#  -0.01743203 -0.03662177  0.03528111 -0.12748449 -0.06664696 -0.15035299
#  -0.01939396  0.08848018]
# No coherence correction applied
# model_chi_real 8.03947994526501
# dof_model_real 18
# model_chi_imag 16.387714587160364
# dof_model_imag 18
# reduced_chi_model 0.6785331814562604
# chi_real_null_cpf 8.725353969523772
# chi_imag_null_cpf 19.65711476197965
# dof_null_real_cpf 20
# dof_null_imag_cpf 20
# reduced_chi_null_cpf 0.7095617182875855
# chi_real_null 9.442183995136325
# chi_imag_null 19.65711476197965
# dof_null_real 20
# dof_null_imag 20
# reduced_chi_null 0.7274824689278994
# Null (1.7213985816667732, 0.16664499804702504, 0.833355001952975, 1.3830647985536106)
# Null CPF (1.457288422722851, 0.2354681906610958, 0.7645318093389042, 1.1863903251408907)

# %%
import numpy as np

# Create a dictionary with all the data used in the plot
plot_data = {
    'av_mod': av_mod,
    'xerr': xerr,
    
    # Top-left: Re G
    'G_real_span': result_L2['G_real_span'],
    'dG_span': result_L2['dG_span'],
    'G_null_real_cpf': result_L2['G_null_real_cpf'],
    'G_null_real': result_L2['G_null_real'],
    'Fit_full_real': result_L2['Fit_full_real'],
    
    # Top-right: Fractional RMS
    'frac_rms': result_L2['frac_rms'],
    'd_frac_rms': result_L2['d_frac_rms'],
    'frac_rms_model': result_L2['frac_rms_model'],
    'frac_rms_null': result_L2['frac_rms_null'],
    'frac_rms_null_cpf': result_L2['frac_rms_null_cpf'],
    
    # Bottom-left: Im G
    'G_im_span': result_L2['G_im_span'],
    'G_null_imag': result_L2['G_null_imag'],
    'G_null_imag_cpf': result_L2['G_null_imag_cpf'],
    'Fit_full_imag': result_L2['Fit_full_imag'],
    
    # Bottom-right: Phase
    'phase_lag': result_L2['phase_lag'],
    'd_phase_lag': result_L2['d_phase_lag'],
    'phase_lag_model': result_L2['phase_lag_model'],
    'phase_lag_null': result_L2['phase_lag_null'],
    'phase_lag_null_cpf': result_L2['phase_lag_null_cpf']
}

# Save as a compressed numpy file
np.savez_compressed('03010001_L2.npz', **plot_data)

# %%
import numpy as np
xerr=(av_mod[1]-av_mod[0])/2
# Create a dictionary with all the data used in the plot
plot_data = {
    'av_mod': av_mod,
    'xerr': xerr,
    
    # Top-left: Re G
    'G_real_span': result_L3['G_real_span'],
    'dG_span': result_L3['dG_span'],
    'G_null_real_cpf': result_L3['G_null_real_cpf'],
    'G_null_real': result_L3['G_null_real'],
    'Fit_full_real': result_L3['Fit_full_real'],
    
    # Top-right: Fractional RMS
    'frac_rms': result_L3['frac_rms'],
    'd_frac_rms': result_L3['d_frac_rms'],
    'frac_rms_model': result_L3['frac_rms_model'],
    'frac_rms_null': result_L3['frac_rms_null'],
    'frac_rms_null_cpf': result_L3['frac_rms_null_cpf'],
    
    # Bottom-left: Im G
    'G_im_span': result_L3['G_im_span'],
    'G_null_imag': result_L3['G_null_imag'],
    'G_null_imag_cpf': result_L3['G_null_imag_cpf'],
    'Fit_full_imag': result_L3['Fit_full_imag'],
    
    # Bottom-right: Phase
    'phase_lag': result_L3['phase_lag'],
    'd_phase_lag': result_L3['d_phase_lag'],
    'phase_lag_model': result_L3['phase_lag_model'],
    'phase_lag_null': result_L3['phase_lag_null'],
    'phase_lag_null_cpf': result_L3['phase_lag_null_cpf']
}

# Save as a compressed numpy file
np.savez_compressed('03010001_L3.npz', **plot_data)
