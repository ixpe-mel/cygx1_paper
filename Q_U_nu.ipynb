# %% [markdown]
# Testing discretised q_u_nu.py file

# %%
import sys
sys.path.append('/home/c2032014/cygx1_paper/')
import q_u_nu as qun
import numpy as np
import importlib
importlib.reload(qun)
# Out:
# <module 'q_u_nu' from '/home/c2032014/cygx1_paper/q_u_nu.py'>

# %%
file1= '/home/c2032014/CYGX1/event_1pt5/ixpe01002901_det12_evt1pt5_v01_src_1.fits'
file2= '/home/c2032014/CYGX1/event_1pt5/ixpe01002901_det3_evt1pt5_v01_src.fits'
Pmin=51
Pmax=200
gti='/home/c2032014/CYGX1/event_1pt5/GTI_ixpe01002901_evt1pt5_v01_src.txt'
bin_length=1/64
seg_length=16
fmin=0
fmax=3
f_bin_number=10
mod_min=np.radians(-90)
mod_max=np.radians(90)
mod_bin_number=20
J=mod_bin_number
spur_sub=True
norm='abs'
coherence_corrector=False

# %%
importlib.reload(qun)
A_real,B_real,C_real,B_imag,C_imag, av_f,norm_factor,G_null_real_arr,G_null_imag_arr=qun.Q_U_NU(file1,file2,Pmin,Pmax,gti,bin_length,seg_length,fmin,fmax,
           f_bin_number,mod_min,mod_max,mod_bin_number,J,
           spur_sub,coherence_corrector)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.0 0.3
# cs_ref_abs_mean 39.53515196566414
# cs nu mag sqrd 1563.0282409481572
# cs_ref_real_mean ie A: 39.52430334162615
# A 0.9782243436655952
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.3 0.6
# cs_ref_abs_mean 15.31919311209511
# cs nu mag sqrd 234.67767760566227
# cs_ref_real_mean ie A: 15.317484137835114
# A 1.066228282878542
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.6 0.8999999999999999
# cs_ref_abs_mean 9.078817686406508
# cs nu mag sqrd 82.42493058300761
# cs_ref_real_mean ie A: 9.078411619974625
# A 1.0300396297715932
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0.8999999999999999 1.2
# cs_ref_abs_mean 6.963927098513702
# cs nu mag sqrd 48.49628063341347
# cs_ref_real_mean ie A: 6.963899711483343
# A 1.3947379175301664
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1.2 1.5
# cs_ref_abs_mean 5.442694361099747
# cs nu mag sqrd 29.62292190834698
# cs_ref_real_mean ie A: 5.442691767402801
# A 1.0690087217274324
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1.5 1.7999999999999998
# cs_ref_abs_mean 4.167574340122438
# cs nu mag sqrd 17.368675880446972
# cs_ref_real_mean ie A: 4.162968307518966
# A 1.2580871539885383
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1.7999999999999998 2.1
# cs_ref_abs_mean 3.0541060357088203
# cs nu mag sqrd 9.327563677353046
# cs_ref_real_mean ie A: 3.0524925461959205
# A 1.05209888127771
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2.1 2.4
# cs_ref_abs_mean 2.3231779930122114
# cs nu mag sqrd 5.397155987216246
# cs_ref_real_mean ie A: 2.3231323378620736
# A 1.1154982026010243
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2.4 2.6999999999999997
# cs_ref_abs_mean 2.0183337656033635
# cs nu mag sqrd 4.073671189374653
# cs_ref_real_mean ie A: 2.0183300818414613
# A 1.1293720630726465
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 2.6999999999999997 3.0
# cs_ref_abs_mean 1.5571699433338266
# cs nu mag sqrd 2.424778232422273
# cs_ref_real_mean ie A: 1.5568960218990344
# A 1.4628676383821448
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
